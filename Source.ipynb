# %%
# %sql
create table if not exists test.default.source_data(
  order_id INT PRIMARY KEY,
  order_date date,
  customer_id VARCHAR(20),
  customer_name VARCHAR(100),
  customer_email VARCHAR(100),
  product_id INT,
  product_name VARCHAR(100),
  product_category VARCHAR(100),
  quantity INT,
  unit_price DECIMAL(10,2),
  payment_type VARCHAR(50),
  country VARCHAR(50),
  last_updated DATE
)

# %%
# %sql
INSERT INTO test.default.source_data VALUES
(1001,'2025-10-31', 'Cust-1', 'Alice Johnson', 'alice@gmail.com', 501, 'Iphone 14', 'Electronics', 1, 999.99,
'Credit Card', 'USA','2025-10-31'),
(1002,'2025-10-31', 'Cust-2', 'Bob Smith', 'Bob@yahoo.com', 502, 'Airpods Pro', 'Electronics', 2, 199.99,
'PayPal', 'USA','2025-10-31'),
(1003,'2025-10-31', 'Cust-3', 'Charlie Brown', 'Charlie@outlook.com', 503, 'Nike Shoes', 'FootWear', 1, 129.99,
'Debit Card', 'Canada','2025-10-31'),
(1004, '2025-11-02', 'Cust-3', 'Charlie Brown', 'CharlieBrn@outlook.com', 503, 'Nike Shoes', 'FootWear', 1, 99.99,
'Credit Card', 'Canada', '2025-11-02'),
(1005, '2025-11-03', 'Cust-2', 'Bob Smith', 'BobSmith@yahoo.com', 502, 'Airpods Pro', 'Electronics', 2, 149.99,
'PayPal', 'USA', '2025-11-03'),
(1006, '2025-11-04', 'Cust-1', 'Alice Johnson', 'alice@gmail.com', 501, 'Iphone 14', 'Electronics', 1, 899.99,
'Credit Card', 'USA', '2025-11-04'),
(1007, '2025-11-05', 'Cust-1', 'Alice Johnson', 'aliceJohn@gmail.com', 504, 'Iphone 15', 'Electronics', 1, 1199.99,
'Credit Card', 'USA', '2025-11-05')
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>7</td><td>7</td></tr></tbody></table></div>
